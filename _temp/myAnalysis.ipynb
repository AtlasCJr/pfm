# %%
from Functions.data_analysis import *
from Functions.edit_database import getTransactionData, getAccount
from Functions.variables import typeMapping
import numpy as np
from scipy.stats import linregress

from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Functions.data_analysis import *
#       2 from Functions.edit_database import getTransactionData, getAccount
#       3 from Functions.variables import typeMapping
#
# ModuleNotFoundError: No module named 'Functions'

# %%
myAcc = getAccount("atlas")

myAcc.summary()
# Out:
#        Username: atlas
#        Password: 1912766d6ba0e50e8b1bacfb51207e83b95b7ac0cd8ce15307cdf4965e7e3f6c
#    Date Created: 2024-07-28 13:26:37
#    Date Updated: 2024-07-28 13:26:37
#         Balance: 10000000

# %%
df = getTransactionData(myAcc)

# %%
DATA = getTimeCycle(df, "year", pos=0)
revenue = DATA[('Revenue', 'TOTAL')]
expenses = DATA[('Expenses', 'TOTAL')]

DATA
# Out:
# 2000-01-01 01:29:33 2023-12-30 22:27:37
#       Expenses                                                                 \
#              0        2        1        3            5         4        TOTAL
# YEAR
# 2000  41478000  4340000  6420000  1550000   50000000.0       0.0  103788000.0
# 2001  40780000  4810000  5950000  2250000          0.0       0.0   53790000.0
# 2002  39985000  6170000  5355000  2400000  550000000.0  450000.0  604360000.0
# 2003  39982000  5620000  5880000  1550000   50000000.0  600000.0  103632000.0
# 2004  41157000  5070000  6745000  2350000          0.0  600000.0   55922000.0
# 2005  39916000  4345000  6775000  3300000          0.0  150000.0   54486000.0
# 2006  40387000  3510000  5720000  1300000   50000000.0  150000.0  101067000.0
# 2007  41107000  4380000  5765000  2500000   50000000.0  150000.0  103902000.0
# 2008  39692000  5070000  5740000  4100000   50000000.0  150000.0  104752000.0
# ...

# %%
DATA['TOTAL'].plot(kind='bar', figsize=(30, 4))
DATA['TOTAL'].plot(color='red')
plt.grid(True, axis='y')
plt.title("Financial Transactions and Adjustments", pad=30)
plt.xlabel("Time", labelpad=20)
plt.ylabel("Rp.", labelpad=20)
plt.xticks(rotation=30)
plt.show()

# %%
revenue.plot(kind='bar', figsize=(15, 4), color='green')
(-expenses).plot(kind='bar', figsize=(15, 4), color='red')
plt.grid(True, axis='y')
plt.title("Expenses and Revenue", pad=30)
plt.xlabel("Time", labelpad=20)
plt.ylabel("Rp.", labelpad=20)
plt.xticks(rotation=30)
plt.legend(["Revenue", "Expenses"])
plt.show()
